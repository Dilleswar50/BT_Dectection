# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns


import os
import random

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
import cv2

import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.applications import VGG19
from tensorflow.keras.optimizers import Adam, Adamax
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Activation, Dropout, BatchNormalization
from tensorflow.keras import regularizers

# %%
data_path = '/content/drive/MyDrive/Shuffeled_BT_Dataset'

# %%
def main(train_data_path):

    """
    return training and testing dataframes including 2 columns image path and its label

    Args:
      train_data_path (string): string includes your train data path
      test_data_path (string): string includes your test data path
      note: data_path argument must contains your classes dirs

    Returns:
      train_df (dataframe):  It consists of two columns (the path of the image and its label) and contains records of the path of the training images and the label of each image
      test_df (dataframe):  It consists of two columns (the path of the image and its label) and contains records of the path of the testing images and the label of each image

    """

    for dirs in [train_data_path]:

        filepaths = []
        labels = []
        classes_list = sorted(os.listdir(dirs))

        filepaths,labels = get_fileList(classes_list, dirs, filepaths, labels)

        train_df = obtain_train_df(filepaths, labels)


    return train_df



def get_fileList(classes_list, dirs, filepaths, labels):


    """
    return file paths list including all full image paths and label for each one

    Args:
      classes_list (list): list includes name of classes dirs
      dirs (string): the data path
      filepaths (list): empty list to fill with images paths later
      labels (list): empty list to fill with each image label later

    Returns:
      count (scalar):  number of images in your dataset
    """


    for s_class in classes_list:

        label = s_class
        classpath = os.path.join(dirs, s_class)
        flist = sorted(os.listdir(classpath))

        store_image_names_and_its_labels(flist, classpath, filepaths, labels, label)

    return filepaths, labels


def store_image_names_and_its_labels(flist, classpath, filepaths, labels, label):

    """
    return nothing, it fills the filepaths list with all the images paths and its labels

    Args:
      flist (list) : contains all the image names in certain class
      classes_list (list): list includes name of classes dirs
      filepaths (list): stores all the images paths
      labels (list): stores the label of each image in the dataset
      label (string): label for a specific image

    Returns:
      nothing
    """


    for file in flist:
        file_path = os.path.join(classpath, file)
        filepaths.append(file_path)
        labels.append(label)



def obtain_train_df(filepaths, labels):

    """
    Return Dataframe with 2 columns contains each image path with its label

    Args:
      filepaths (list): stores all the images paths
      labels (list): stores the label of each image in the dataset

    Returns:
      train_df (DataFrame):  Dataframe with 2 columns contains each image path with its label
    """

    train_df =pd.DataFrame({
        'image_path' : filepaths,
        'label' : labels
    })
    return train_df

# %%
data_df = main(data_path)

# %%
data_df.head()
# Out:
#                                           image_path           label
# 0  /content/drive/MyDrive/Shuffeled_BT_Dataset/As...  Astrocitoma T1
# 1  /content/drive/MyDrive/Shuffeled_BT_Dataset/As...  Astrocitoma T1
# 2  /content/drive/MyDrive/Shuffeled_BT_Dataset/As...  Astrocitoma T1
# 3  /content/drive/MyDrive/Shuffeled_BT_Dataset/As...  Astrocitoma T1
# 4  /content/drive/MyDrive/Shuffeled_BT_Dataset/As...  Astrocitoma T1

# %%
num_classes = len(data_df['label'].unique())
print(f"We have {num_classes} classes")
print(f"We have {data_df.shape[0]} images")
# Out:
# We have 44 classes
# We have 4497 images

# %%
data_df['label'].value_counts()
# Out:
# Meningioma T1C+           375
# _NORMAL T2                277
# Meningioma T1             272
# _NORMAL T1                251
# Astrocitoma T1C+          233
# Meningioma T2             233
# Neurocitoma T1C+          223
# Schwannoma T1C+           194
# Astrocitoma T1            176
# Astrocitoma T2            171
# Schwannoma T1             148
# Neurocitoma T1            130
# Schwannoma T2             129
# Carcinoma T1C+            112
# Papiloma T1C+             108
# Neurocitoma T2            104
# Glioblastoma T1C+          94
# Oligodendroglioma T1       86
# Tuberculoma T1C+           84
# Carcinoma T2               73
# Oligodendroglioma T1C+     72
# Meduloblastoma T1C+        67
# Papiloma T1                66
# Oligodendroglioma T2       66
# Carcinoma T1               66
# Papiloma T2                63
# Ependimoma T2              57
# Glioblastoma T2            55
# Glioblastoma T1            55
# Ependimoma T1C+            48
# Ependimoma T1              45
# Meduloblastoma T2          41
# Germinoma T1C+             40
# Tuberculoma T2             33
# Germinoma T2               33
# Granuloma T1C+             31
# Granuloma T1               30
# Tuberculoma T1             28
# Germinoma T1               27
# Ganglioglioma T2           23
# Meduloblastoma T1          23
# Ganglioglioma T1           20
# Ganglioglioma T1C+         18
# Granuloma T2               17
# Name: label, dtype: int64

# %%
def count_plot(x, title, xlabel, ylabel, width, length, order = None, rotation=False, palette='winter'):
    plt.figure(figsize=(width,length))
    sns.countplot(x = x, palette=palette, order = order)
    plt.title(title, fontsize=25)
    if rotation:
        plt.xticks(rotation = 'vertical')
    plt.xlabel(xlabel, fontsize=20)
    plt.ylabel(ylabel, fontsize=20)
    plt.show()

# %%
x = data_df['label']
order = x.value_counts().index
count_plot(x, "Labels distribution (Train Data)", "Label", 'Frequency', 15,12, rotation = True, order=order)

# %%
test_split_size = 0.3
train_df, test_df = train_test_split(data_df, test_size=test_split_size, shuffle=True, random_state=123, stratify=data_df['label'])
test_df, valid_df = train_test_split(test_df, test_size=0.5, shuffle=True, random_state=123, stratify=test_df['label'])

# %%
x = train_df['label']
order = x.value_counts().index
count_plot(x, "Labels distribution (Train Data)", "Label", 'Frequency', 15,12, rotation = True, order=order)

# %%
train_df.head()
# Out:
#                                              image_path           label
# 3972  /content/drive/MyDrive/Shuffeled_BT_Dataset/_N...      _NORMAL T1
# 3334  /content/drive/MyDrive/Shuffeled_BT_Dataset/Pa...     Papiloma T2
# 2885  /content/drive/MyDrive/Shuffeled_BT_Dataset/Ne...  Neurocitoma T2
# 1687  /content/drive/MyDrive/Shuffeled_BT_Dataset/Me...   Meningioma T1
# 1381  /content/drive/MyDrive/Shuffeled_BT_Dataset/Gr...  Granuloma T1C+

# %%
test_df.head()
# Out:
#                                              image_path                label
# 2323  /content/drive/MyDrive/Shuffeled_BT_Dataset/Me...        Meningioma T2
# 288   /content/drive/MyDrive/Shuffeled_BT_Dataset/As...     Astrocitoma T1C+
# 3229  /content/drive/MyDrive/Shuffeled_BT_Dataset/Pa...        Papiloma T1C+
# 1496  /content/drive/MyDrive/Shuffeled_BT_Dataset/Me...  Meduloblastoma T1C+
# 3327  /content/drive/MyDrive/Shuffeled_BT_Dataset/Pa...          Papiloma T2

# %%
x = test_df['label']
order = x.value_counts().index
count_plot(x, "Labels distribution (Test Data)", "Label", 'Frequency', 15,12, rotation = True, order=order)

# %%
valid_df.head()
# Out:
#                                              image_path             label
# 2730  /content/drive/MyDrive/Shuffeled_BT_Dataset/Ne...  Neurocitoma T1C+
# 300   /content/drive/MyDrive/Shuffeled_BT_Dataset/As...  Astrocitoma T1C+
# 553   /content/drive/MyDrive/Shuffeled_BT_Dataset/As...    Astrocitoma T2
# 4000  /content/drive/MyDrive/Shuffeled_BT_Dataset/_N...        _NORMAL T1
# 892   /content/drive/MyDrive/Shuffeled_BT_Dataset/Ep...   Ependimoma T1C+

# %%
x = valid_df['label']
order = x.value_counts().index
count_plot(x, "Labels distribution (Valid Data)", "Label", 'Frequency', 15,12, rotation = True, order=order)

# %%
print(f"We have {len(train_df)} images in the training dataset\nWe have {len(valid_df)} images in the validating dataset\nWe have {len(test_df)} images in the testing dataset")
# Out:
# We have 3147 images in the training dataset
# We have 675 images in the validating dataset
# We have 675 images in the testing dataset

# %%
len(data_df)
# Out:
# 4497

# %%
img_size = (224, 224)
channels = 3
color = 'rgb'
img_shape = (img_size[0], img_size[1], channels)
batch_size = 32
ts_length = len(test_df)
test_batch_size = max(sorted([ts_length // n for n in range(1, ts_length + 1) if ts_length%n == 0 and ts_length/n <= 80]))
test_steps = ts_length // test_batch_size
def scalar(img):
    return img

# %%
tr_gen = ImageDataGenerator(preprocessing_function= scalar,
                            horizontal_flip= True)

ts_gen = ImageDataGenerator(preprocessing_function= scalar)

train_gen = tr_gen.flow_from_dataframe( train_df,
                                       x_col= 'image_path',
                                       y_col= 'label',
                                       target_size= img_size,
                                       class_mode= 'categorical',
                                       color_mode= color,
                                       shuffle= True,
                                       batch_size= batch_size)

valid_gen = ts_gen.flow_from_dataframe( valid_df,
                                       x_col= 'image_path',
                                       y_col= 'label',
                                       target_size= img_size,
                                       class_mode= 'categorical',
                                       color_mode= color,
                                       shuffle= True,
                                       batch_size= batch_size)

test_gen = ts_gen.flow_from_dataframe( test_df,
                                      x_col= 'image_path',
                                      y_col= 'label',
                                      target_size= img_size,
                                      class_mode= 'categorical',
                                      color_mode= color,
                                      shuffle= False,
                                      batch_size= test_batch_size)
# Out:
# Found 3146 validated image filenames belonging to 44 classes.
# Found 675 validated image filenames belonging to 44 classes.
# /usr/local/lib/python3.10/dist-packages/keras/src/preprocessing/image.py:1137: UserWarning: Found 1 invalid image filename(s) in x_col="image_path". These filename(s) will be ignored.
#   warnings.warn(
# Found 675 validated image filenames belonging to 44 classes.

# %%
class_count = len(list(train_gen.class_indices.keys()))

# %%
base_model = tf.keras.applications.efficientnet.EfficientNetB5(include_top= False,
                                                               weights= "imagenet",
                                                               input_shape= img_shape,
                                                               pooling= 'max')

model = Sequential([
    base_model,
    BatchNormalization(axis= -1, momentum= 0.99, epsilon= 0.001),
    Dense(256,
          kernel_regularizer= regularizers.l2(l= 0.016),
          activity_regularizer= regularizers.l1(0.006),
          bias_regularizer= regularizers.l1(0.006),
          activation= 'relu'),

    Dropout(rate= 0.45,
            seed= 123),

    Dense(class_count, activation= 'softmax')
])

model.compile(Adamax(learning_rate= 0.001), loss= 'categorical_crossentropy', metrics= ['accuracy'])

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb5_notop.h5
# 115263384/115263384 [==============================] - 1s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb5 (Functional  (None, 2048)              28513527
#  )
#
#  batch_normalization (Batch  (None, 2048)              8192
#  Normalization)
#
#  dense (Dense)               (None, 256)               524544
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 44)                11308
#
# =================================================================
# Total params: 29057571 (110.85 MB)
# Trainable params: 28880732 (110.17 MB)
# Non-trainable params: 176839 (690.78 KB)
# _________________________________________________________________

# %%
#info about optimizers
model.optimizer.get_config()
# Out:
# {'name': 'Adamax',
#  'weight_decay': None,
#  'clipnorm': None,
#  'global_clipnorm': None,
#  'clipvalue': None,
#  'use_ema': False,
#  'ema_momentum': 0.99,
#  'ema_overwrite_frequency': None,
#  'jit_compile': True,
#  'is_legacy_optimizer': False,
#  'learning_rate': 0.001,
#  'beta_1': 0.9,
#  'beta_2': 0.999,
#  'epsilon': 1e-07}

# %%
early_stop = EarlyStopping(monitor='val_loss',
                           patience=5,
                           verbose=1)

checkpoint = ModelCheckpoint('model_weights.h5',
                             monitor='val_loss',
                             save_best_only=True,
                             save_weights_only=True,
                             mode='min',
                             verbose=1)


history = model.fit(x= train_gen,
                    steps_per_epoch = 20,
                    epochs= 100,
                    callbacks=[early_stop, checkpoint],
                    validation_data= valid_gen)
# Out:
# Epoch 1/100
# 20/20 [==============================] - ETA: 0s - loss: 11.7961 - accuracy: 0.1570
# Epoch 1: val_loss improved from inf to 15.21183, saving model to model_weights.h5
# 20/20 [==============================] - 482s 19s/step - loss: 11.7961 - accuracy: 0.1570 - val_loss: 15.2118 - val_accuracy: 0.0993
# Epoch 2/100
# 20/20 [==============================] - ETA: 0s - loss: 10.4088 - accuracy: 0.3544
# Epoch 2: val_loss improved from 15.21183 to 12.31572, saving model to model_weights.h5
# 20/20 [==============================] - 157s 8s/step - loss: 10.4088 - accuracy: 0.3544 - val_loss: 12.3157 - val_accuracy: 0.1822
# Epoch 3/100
# 20/20 [==============================] - ETA: 0s - loss: 9.6486 - accuracy: 0.4250
# Epoch 3: val_loss improved from 12.31572 to 10.78134, saving model to model_weights.h5
# 20/20 [==============================] - 130s 6s/step - loss: 9.6486 - accuracy: 0.4250 - val_loss: 10.7813 - val_accuracy: 0.3289
# Epoch 4/100
# 20/20 [==============================] - ETA: 0s - loss: 8.9339 - accuracy: 0.5688
# Epoch 4: val_loss improved from 10.78134 to 10.02503, saving model to model_weights.h5
# 20/20 [==============================] - 100s 5s/step - loss: 8.9339 - accuracy: 0.5688 - val_loss: 10.0250 - val_accuracy: 0.3437
# Epoch 5/100
# 20/20 [==============================] - ETA: 0s - loss: 8.4201 - accuracy: 0.6181
# Epoch 5: val_loss improved from 10.02503 to 9.04937, saving model to model_weights.h5
# 20/20 [==============================] - 81s 4s/step - loss: 8.4201 - accuracy: 0.6181 - val_loss: 9.0494 - val_accuracy: 0.4652
# Epoch 6/100
# 20/20 [==============================] - ETA: 0s - loss: 8.0370 - accuracy: 0.6641
# Epoch 6: val_loss improved from 9.04937 to 8.30314, saving model to model_weights.h5
# 20/20 [==============================] - 64s 3s/step - loss: 8.0370 - accuracy: 0.6641 - val_loss: 8.3031 - val_accuracy: 0.5570
# Epoch 7/100
# 20/20 [==============================] - ETA: 0s - loss: 7.6591 - accuracy: 0.7031
# Epoch 7: val_loss improved from 8.30314 to 7.98841, saving model to model_weights.h5
# 20/20 [==============================] - 52s 3s/step - loss: 7.6591 - accuracy: 0.7031 - val_loss: 7.9884 - val_accuracy: 0.5422
# Epoch 8/100
# 20/20 [==============================] - ETA: 0s - loss: 7.1641 - accuracy: 0.7672
# Epoch 8: val_loss improved from 7.98841 to 7.61645, saving model to model_weights.h5
# 20/20 [==============================] - 44s 2s/step - loss: 7.1641 - accuracy: 0.7672 - val_loss: 7.6165 - val_accuracy: 0.5837
# Epoch 9/100
# 20/20 [==============================] - ETA: 0s - loss: 6.9312 - accuracy: 0.7686
# Epoch 9: val_loss improved from 7.61645 to 7.19399, saving model to model_weights.h5
# 20/20 [==============================] - 32s 2s/step - loss: 6.9312 - accuracy: 0.7686 - val_loss: 7.1940 - val_accuracy: 0.6444
# Epoch 10/100
# 20/20 [==============================] - ETA: 0s - loss: 6.6392 - accuracy: 0.7937
# Epoch 10: val_loss improved from 7.19399 to 6.83266, saving model to model_weights.h5
# 20/20 [==============================] - 32s 2s/step - loss: 6.6392 - accuracy: 0.7937 - val_loss: 6.8327 - val_accuracy: 0.7126
# Epoch 11/100
# 20/20 [==============================] - ETA: 0s - loss: 6.3937 - accuracy: 0.8094
# Epoch 11: val_loss improved from 6.83266 to 6.55659, saving model to model_weights.h5
# 20/20 [==============================] - 27s 1s/step - loss: 6.3937 - accuracy: 0.8094 - val_loss: 6.5566 - val_accuracy: 0.7230
# Epoch 12/100
# 20/20 [==============================] - ETA: 0s - loss: 6.0851 - accuracy: 0.8375
# Epoch 12: val_loss improved from 6.55659 to 6.24129, saving model to model_weights.h5
# 20/20 [==============================] - 24s 1s/step - loss: 6.0851 - accuracy: 0.8375 - val_loss: 6.2413 - val_accuracy: 0.7630
# Epoch 13/100
# 20/20 [==============================] - ETA: 0s - loss: 5.8424 - accuracy: 0.8641
# Epoch 13: val_loss improved from 6.24129 to 5.95772, saving model to model_weights.h5
# 20/20 [==============================] - 24s 1s/step - loss: 5.8424 - accuracy: 0.8641 - val_loss: 5.9577 - val_accuracy: 0.7793
# Epoch 14/100
# 20/20 [==============================] - ETA: 0s - loss: 5.5983 - accuracy: 0.8719
# Epoch 14: val_loss improved from 5.95772 to 5.76129, saving model to model_weights.h5
# 20/20 [==============================] - 24s 1s/step - loss: 5.5983 - accuracy: 0.8719 - val_loss: 5.7613 - val_accuracy: 0.7807
# Epoch 15/100
# 20/20 [==============================] - ETA: 0s - loss: 5.3670 - accuracy: 0.8750
# Epoch 15: val_loss improved from 5.76129 to 5.54239, saving model to model_weights.h5
# 20/20 [==============================] - 24s 1s/step - loss: 5.3670 - accuracy: 0.8750 - val_loss: 5.5424 - val_accuracy: 0.8089
# Epoch 16/100
# 20/20 [==============================] - ETA: 0s - loss: 5.0778 - accuracy: 0.9016
# Epoch 16: val_loss improved from 5.54239 to 5.29551, saving model to model_weights.h5
# 20/20 [==============================] - 24s 1s/step - loss: 5.0778 - accuracy: 0.9016 - val_loss: 5.2955 - val_accuracy: 0.8059
# Epoch 17/100
# 20/20 [==============================] - ETA: 0s - loss: 4.8678 - accuracy: 0.9234
# Epoch 17: val_loss improved from 5.29551 to 5.07682, saving model to model_weights.h5
# 20/20 [==============================] - 24s 1s/step - loss: 4.8678 - accuracy: 0.9234 - val_loss: 5.0768 - val_accuracy: 0.8089
# Epoch 18/100
# 20/20 [==============================] - ETA: 0s - loss: 4.6831 - accuracy: 0.9359
# Epoch 18: val_loss improved from 5.07682 to 4.87375, saving model to model_weights.h5
# 20/20 [==============================] - 25s 1s/step - loss: 4.6831 - accuracy: 0.9359 - val_loss: 4.8738 - val_accuracy: 0.8296
# Epoch 19/100
# 20/20 [==============================] - ETA: 0s - loss: 4.5011 - accuracy: 0.9219
# Epoch 19: val_loss improved from 4.87375 to 4.72516, saving model to model_weights.h5
# 20/20 [==============================] - 24s 1s/step - loss: 4.5011 - accuracy: 0.9219 - val_loss: 4.7252 - val_accuracy: 0.8281
# Epoch 20/100
# 20/20 [==============================] - ETA: 0s - loss: 4.3104 - accuracy: 0.9391
# Epoch 20: val_loss improved from 4.72516 to 4.55232, saving model to model_weights.h5
# 20/20 [==============================] - 24s 1s/step - loss: 4.3104 - accuracy: 0.9391 - val_loss: 4.5523 - val_accuracy: 0.8222
# Epoch 21/100
# 20/20 [==============================] - ETA: 0s - loss: 4.1572 - accuracy: 0.9328
# Epoch 21: val_loss improved from 4.55232 to 4.33890, saving model to model_weights.h5
# 20/20 [==============================] - 24s 1s/step - loss: 4.1572 - accuracy: 0.9328 - val_loss: 4.3389 - val_accuracy: 0.8356
# Epoch 22/100
# 20/20 [==============================] - ETA: 0s - loss: 3.9417 - accuracy: 0.9656
# Epoch 22: val_loss improved from 4.33890 to 4.13231, saving model to model_weights.h5
# 20/20 [==============================] - 24s 1s/step - loss: 3.9417 - accuracy: 0.9656 - val_loss: 4.1323 - val_accuracy: 0.8652
# Epoch 23/100
# 20/20 [==============================] - ETA: 0s - loss: 3.8190 - accuracy: 0.9484
# Epoch 23: val_loss improved from 4.13231 to 3.93761, saving model to model_weights.h5
# 20/20 [==============================] - 23s 1s/step - loss: 3.8190 - accuracy: 0.9484 - val_loss: 3.9376 - val_accuracy: 0.8815
# Epoch 24/100
# 20/20 [==============================] - ETA: 0s - loss: 3.6457 - accuracy: 0.9563
# Epoch 24: val_loss improved from 3.93761 to 3.80816, saving model to model_weights.h5
# 20/20 [==============================] - 24s 1s/step - loss: 3.6457 - accuracy: 0.9563 - val_loss: 3.8082 - val_accuracy: 0.8726
# Epoch 25/100
# 20/20 [==============================] - ETA: 0s - loss: 3.4965 - accuracy: 0.9625
# Epoch 25: val_loss improved from 3.80816 to 3.63730, saving model to model_weights.h5
# 20/20 [==============================] - 24s 1s/step - loss: 3.4965 - accuracy: 0.9625 - val_loss: 3.6373 - val_accuracy: 0.8904
# Epoch 26/100
# 20/20 [==============================] - ETA: 0s - loss: 3.3566 - accuracy: 0.9656
# Epoch 26: val_loss improved from 3.63730 to 3.46107, saving model to model_weights.h5
# 20/20 [==============================] - 24s 1s/step - loss: 3.3566 - accuracy: 0.9656 - val_loss: 3.4611 - val_accuracy: 0.8978
# Epoch 27/100
# 20/20 [==============================] - ETA: 0s - loss: 3.2151 - accuracy: 0.9709
# Epoch 27: val_loss improved from 3.46107 to 3.35466, saving model to model_weights.h5
# 20/20 [==============================] - 23s 1s/step - loss: 3.2151 - accuracy: 0.9709 - val_loss: 3.3547 - val_accuracy: 0.8919
# Epoch 28/100
# 20/20 [==============================] - ETA: 0s - loss: 3.0995 - accuracy: 0.9688
# Epoch 28: val_loss improved from 3.35466 to 3.18879, saving model to model_weights.h5
# 20/20 [==============================] - 23s 1s/step - loss: 3.0995 - accuracy: 0.9688 - val_loss: 3.1888 - val_accuracy: 0.9126
# Epoch 29/100
# 20/20 [==============================] - ETA: 0s - loss: 2.9458 - accuracy: 0.9797
# Epoch 29: val_loss improved from 3.18879 to 3.05401, saving model to model_weights.h5
# 20/20 [==============================] - 24s 1s/step - loss: 2.9458 - accuracy: 0.9797 - val_loss: 3.0540 - val_accuracy: 0.9022
# Epoch 30/100
# 20/20 [==============================] - ETA: 0s - loss: 2.8254 - accuracy: 0.9797
# Epoch 30: val_loss improved from 3.05401 to 2.95894, saving model to model_weights.h5
# 20/20 [==============================] - 24s 1s/step - loss: 2.8254 - accuracy: 0.9797 - val_loss: 2.9589 - val_accuracy: 0.9007
# Epoch 31/100
# 20/20 [==============================] - ETA: 0s - loss: 2.6838 - accuracy: 0.9875
# Epoch 31: val_loss improved from 2.95894 to 2.81074, saving model to model_weights.h5
# 20/20 [==============================] - 23s 1s/step - loss: 2.6838 - accuracy: 0.9875 - val_loss: 2.8107 - val_accuracy: 0.9170
# Epoch 32/100
# 20/20 [==============================] - ETA: 0s - loss: 2.5574 - accuracy: 0.9859
# Epoch 32: val_loss improved from 2.81074 to 2.70152, saving model to model_weights.h5
# 20/20 [==============================] - 24s 1s/step - loss: 2.5574 - accuracy: 0.9859 - val_loss: 2.7015 - val_accuracy: 0.9259
# Epoch 33/100
# 20/20 [==============================] - ETA: 0s - loss: 2.4455 - accuracy: 0.9922
# Epoch 33: val_loss improved from 2.70152 to 2.59264, saving model to model_weights.h5
# 20/20 [==============================] - 24s 1s/step - loss: 2.4455 - accuracy: 0.9922 - val_loss: 2.5926 - val_accuracy: 0.9259
# Epoch 34/100
# 20/20 [==============================] - ETA: 0s - loss: 2.3859 - accuracy: 0.9844
# Epoch 34: val_loss improved from 2.59264 to 2.51018, saving model to model_weights.h5
# 20/20 [==============================] - 24s 1s/step - loss: 2.3859 - accuracy: 0.9844 - val_loss: 2.5102 - val_accuracy: 0.9156
# Epoch 35/100
# 20/20 [==============================] - ETA: 0s - loss: 2.2622 - accuracy: 0.9875
# Epoch 35: val_loss improved from 2.51018 to 2.39700, saving model to model_weights.h5
# 20/20 [==============================] - 24s 1s/step - loss: 2.2622 - accuracy: 0.9875 - val_loss: 2.3970 - val_accuracy: 0.9185
# Epoch 36/100
# 20/20 [==============================] - ETA: 0s - loss: 2.1663 - accuracy: 0.9891
# Epoch 36: val_loss improved from 2.39700 to 2.31424, saving model to model_weights.h5
# 20/20 [==============================] - 24s 1s/step - loss: 2.1663 - accuracy: 0.9891 - val_loss: 2.3142 - val_accuracy: 0.9096
# Epoch 37/100
# 20/20 [==============================] - ETA: 0s - loss: 2.1186 - accuracy: 0.9797
# Epoch 37: val_loss improved from 2.31424 to 2.22273, saving model to model_weights.h5
# 20/20 [==============================] - 24s 1s/step - loss: 2.1186 - accuracy: 0.9797 - val_loss: 2.2227 - val_accuracy: 0.9170
# Epoch 38/100
# 20/20 [==============================] - ETA: 0s - loss: 2.0033 - accuracy: 0.9828
# Epoch 38: val_loss improved from 2.22273 to 2.13251, saving model to model_weights.h5
# 20/20 [==============================] - 23s 1s/step - loss: 2.0033 - accuracy: 0.9828 - val_loss: 2.1325 - val_accuracy: 0.9319
# Epoch 39/100
# 20/20 [==============================] - ETA: 0s - loss: 1.9326 - accuracy: 0.9859
# Epoch 39: val_loss improved from 2.13251 to 2.04363, saving model to model_weights.h5
# 20/20 [==============================] - 24s 1s/step - loss: 1.9326 - accuracy: 0.9859 - val_loss: 2.0436 - val_accuracy: 0.9333
# Epoch 40/100
# 20/20 [==============================] - ETA: 0s - loss: 1.8426 - accuracy: 0.9844
# Epoch 40: val_loss improved from 2.04363 to 1.95648, saving model to model_weights.h5
# 20/20 [==============================] - 24s 1s/step - loss: 1.8426 - accuracy: 0.9844 - val_loss: 1.9565 - val_accuracy: 0.9348
# Epoch 41/100
# 20/20 [==============================] - ETA: 0s - loss: 1.7523 - accuracy: 0.9922
# Epoch 41: val_loss improved from 1.95648 to 1.88417, saving model to model_weights.h5
# 20/20 [==============================] - 24s 1s/step - loss: 1.7523 - accuracy: 0.9922 - val_loss: 1.8842 - val_accuracy: 0.9363
# Epoch 42/100
# 20/20 [==============================] - ETA: 0s - loss: 1.6956 - accuracy: 0.9891
# Epoch 42: val_loss improved from 1.88417 to 1.80163, saving model to model_weights.h5
# 20/20 [==============================] - 24s 1s/step - loss: 1.6956 - accuracy: 0.9891 - val_loss: 1.8016 - val_accuracy: 0.9333
# Epoch 43/100
# 20/20 [==============================] - ETA: 0s - loss: 1.6231 - accuracy: 0.9891
# Epoch 43: val_loss improved from 1.80163 to 1.74088, saving model to model_weights.h5
# 20/20 [==============================] - 23s 1s/step - loss: 1.6231 - accuracy: 0.9891 - val_loss: 1.7409 - val_accuracy: 0.9378
# Epoch 44/100
# 20/20 [==============================] - ETA: 0s - loss: 1.5512 - accuracy: 0.9922
# Epoch 44: val_loss improved from 1.74088 to 1.67417, saving model to model_weights.h5
# 20/20 [==============================] - 23s 1s/step - loss: 1.5512 - accuracy: 0.9922 - val_loss: 1.6742 - val_accuracy: 0.9378
# Epoch 45/100
# 20/20 [==============================] - ETA: 0s - loss: 1.4703 - accuracy: 0.9951
# Epoch 45: val_loss improved from 1.67417 to 1.62440, saving model to model_weights.h5
# 20/20 [==============================] - 23s 1s/step - loss: 1.4703 - accuracy: 0.9951 - val_loss: 1.6244 - val_accuracy: 0.9348
# Epoch 46/100
# 20/20 [==============================] - ETA: 0s - loss: 1.4237 - accuracy: 0.9891
# Epoch 46: val_loss improved from 1.62440 to 1.56426, saving model to model_weights.h5
# 20/20 [==============================] - 23s 1s/step - loss: 1.4237 - accuracy: 0.9891 - val_loss: 1.5643 - val_accuracy: 0.9407
# Epoch 47/100
# 20/20 [==============================] - ETA: 0s - loss: 1.3871 - accuracy: 0.9903
# Epoch 47: val_loss improved from 1.56426 to 1.53466, saving model to model_weights.h5
# 20/20 [==============================] - 23s 1s/step - loss: 1.3871 - accuracy: 0.9903 - val_loss: 1.5347 - val_accuracy: 0.9274
# Epoch 48/100
# 20/20 [==============================] - ETA: 0s - loss: 1.3263 - accuracy: 0.9903
# Epoch 48: val_loss improved from 1.53466 to 1.49289, saving model to model_weights.h5
# 20/20 [==============================] - 23s 1s/step - loss: 1.3263 - accuracy: 0.9903 - val_loss: 1.4929 - val_accuracy: 0.9274
# Epoch 49/100
# 20/20 [==============================] - ETA: 0s - loss: 1.2648 - accuracy: 0.9953
# Epoch 49: val_loss improved from 1.49289 to 1.44193, saving model to model_weights.h5
# 20/20 [==============================] - 24s 1s/step - loss: 1.2648 - accuracy: 0.9953 - val_loss: 1.4419 - val_accuracy: 0.9244
# Epoch 50/100
# 20/20 [==============================] - ETA: 0s - loss: 1.2302 - accuracy: 0.9891
# Epoch 50: val_loss improved from 1.44193 to 1.40636, saving model to model_weights.h5
# 20/20 [==============================] - 23s 1s/step - loss: 1.2302 - accuracy: 0.9891 - val_loss: 1.4064 - val_accuracy: 0.9141
# Epoch 51/100
# 20/20 [==============================] - ETA: 0s - loss: 1.1871 - accuracy: 0.9875
# Epoch 51: val_loss improved from 1.40636 to 1.34989, saving model to model_weights.h5
# 20/20 [==============================] - 24s 1s/step - loss: 1.1871 - accuracy: 0.9875 - val_loss: 1.3499 - val_accuracy: 0.9274
# Epoch 52/100
# 20/20 [==============================] - ETA: 0s - loss: 1.1372 - accuracy: 0.9937
# Epoch 52: val_loss improved from 1.34989 to 1.28012, saving model to model_weights.h5
# 20/20 [==============================] - 24s 1s/step - loss: 1.1372 - accuracy: 0.9937 - val_loss: 1.2801 - val_accuracy: 0.9348
# Epoch 53/100
# 20/20 [==============================] - ETA: 0s - loss: 1.0915 - accuracy: 0.9937
# Epoch 53: val_loss improved from 1.28012 to 1.24117, saving model to model_weights.h5
# 20/20 [==============================] - 24s 1s/step - loss: 1.0915 - accuracy: 0.9937 - val_loss: 1.2412 - val_accuracy: 0.9363
# Epoch 54/100
# 20/20 [==============================] - ETA: 0s - loss: 1.0571 - accuracy: 0.9922
# Epoch 54: val_loss improved from 1.24117 to 1.20865, saving model to model_weights.h5
# 20/20 [==============================] - 23s 1s/step - loss: 1.0571 - accuracy: 0.9922 - val_loss: 1.2086 - val_accuracy: 0.9333
# Epoch 55/100
# 20/20 [==============================] - ETA: 0s - loss: 1.0271 - accuracy: 0.9891
# Epoch 55: val_loss improved from 1.20865 to 1.17694, saving model to model_weights.h5
# 20/20 [==============================] - 24s 1s/step - loss: 1.0271 - accuracy: 0.9891 - val_loss: 1.1769 - val_accuracy: 0.9304
# Epoch 56/100
# 20/20 [==============================] - ETA: 0s - loss: 0.9785 - accuracy: 0.9953
# Epoch 56: val_loss improved from 1.17694 to 1.13467, saving model to model_weights.h5
# 20/20 [==============================] - 24s 1s/step - loss: 0.9785 - accuracy: 0.9953 - val_loss: 1.1347 - val_accuracy: 0.9422
# Epoch 57/100
# 20/20 [==============================] - ETA: 0s - loss: 0.9671 - accuracy: 0.9871
# Epoch 57: val_loss did not improve from 1.13467
# 20/20 [==============================] - 22s 1s/step - loss: 0.9671 - accuracy: 0.9871 - val_loss: 1.1407 - val_accuracy: 0.9304
# Epoch 58/100
# 20/20 [==============================] - ETA: 0s - loss: 0.9511 - accuracy: 0.9891
# Epoch 58: val_loss improved from 1.13467 to 1.07302, saving model to model_weights.h5
# 20/20 [==============================] - 24s 1s/step - loss: 0.9511 - accuracy: 0.9891 - val_loss: 1.0730 - val_accuracy: 0.9348
# Epoch 59/100
# 20/20 [==============================] - ETA: 0s - loss: 0.9094 - accuracy: 0.9906
# Epoch 59: val_loss improved from 1.07302 to 1.06359, saving model to model_weights.h5
# 20/20 [==============================] - 24s 1s/step - loss: 0.9094 - accuracy: 0.9906 - val_loss: 1.0636 - val_accuracy: 0.9407
# Epoch 60/100
# 20/20 [==============================] - ETA: 0s - loss: 0.8819 - accuracy: 0.9937
# Epoch 60: val_loss improved from 1.06359 to 1.02269, saving model to model_weights.h5
# 20/20 [==============================] - 24s 1s/step - loss: 0.8819 - accuracy: 0.9937 - val_loss: 1.0227 - val_accuracy: 0.9393
# Epoch 61/100
# 20/20 [==============================] - ETA: 0s - loss: 0.8369 - accuracy: 1.0000
# Epoch 61: val_loss improved from 1.02269 to 0.99674, saving model to model_weights.h5
# 20/20 [==============================] - 23s 1s/step - loss: 0.8369 - accuracy: 1.0000 - val_loss: 0.9967 - val_accuracy: 0.9378
# Epoch 62/100
# 20/20 [==============================] - ETA: 0s - loss: 0.8050 - accuracy: 0.9969
# Epoch 62: val_loss improved from 0.99674 to 0.97257, saving model to model_weights.h5
# 20/20 [==============================] - 24s 1s/step - loss: 0.8050 - accuracy: 0.9969 - val_loss: 0.9726 - val_accuracy: 0.9422
# Epoch 63/100
# 20/20 [==============================] - ETA: 0s - loss: 0.7825 - accuracy: 0.9969
# Epoch 63: val_loss improved from 0.97257 to 0.93821, saving model to model_weights.h5
# 20/20 [==============================] - 24s 1s/step - loss: 0.7825 - accuracy: 0.9969 - val_loss: 0.9382 - val_accuracy: 0.9393
# Epoch 64/100
# 20/20 [==============================] - ETA: 0s - loss: 0.7667 - accuracy: 0.9969
# Epoch 64: val_loss improved from 0.93821 to 0.90786, saving model to model_weights.h5
# 20/20 [==============================] - 23s 1s/step - loss: 0.7667 - accuracy: 0.9969 - val_loss: 0.9079 - val_accuracy: 0.9437
# Epoch 65/100
# 20/20 [==============================] - ETA: 0s - loss: 0.7429 - accuracy: 0.9984
# Epoch 65: val_loss improved from 0.90786 to 0.90070, saving model to model_weights.h5
# 20/20 [==============================] - 23s 1s/step - loss: 0.7429 - accuracy: 0.9984 - val_loss: 0.9007 - val_accuracy: 0.9481
# Epoch 66/100
# 20/20 [==============================] - ETA: 0s - loss: 0.7276 - accuracy: 0.9969
# Epoch 66: val_loss improved from 0.90070 to 0.87862, saving model to model_weights.h5
# 20/20 [==============================] - 24s 1s/step - loss: 0.7276 - accuracy: 0.9969 - val_loss: 0.8786 - val_accuracy: 0.9511
# Epoch 67/100
# 20/20 [==============================] - ETA: 0s - loss: 0.7112 - accuracy: 0.9953
# Epoch 67: val_loss improved from 0.87862 to 0.87276, saving model to model_weights.h5
# 20/20 [==============================] - 23s 1s/step - loss: 0.7112 - accuracy: 0.9953 - val_loss: 0.8728 - val_accuracy: 0.9511
# Epoch 68/100
# 20/20 [==============================] - ETA: 0s - loss: 0.6972 - accuracy: 0.9969
# Epoch 68: val_loss improved from 0.87276 to 0.85700, saving model to model_weights.h5
# 20/20 [==============================] - 24s 1s/step - loss: 0.6972 - accuracy: 0.9969 - val_loss: 0.8570 - val_accuracy: 0.9452
# Epoch 69/100
# 20/20 [==============================] - ETA: 0s - loss: 0.6902 - accuracy: 0.9922
# Epoch 69: val_loss improved from 0.85700 to 0.84130, saving model to model_weights.h5
# 20/20 [==============================] - 24s 1s/step - loss: 0.6902 - accuracy: 0.9922 - val_loss: 0.8413 - val_accuracy: 0.9363
# Epoch 70/100
# 20/20 [==============================] - ETA: 0s - loss: 0.6771 - accuracy: 0.9935
# Epoch 70: val_loss improved from 0.84130 to 0.81585, saving model to model_weights.h5
# 20/20 [==============================] - 23s 1s/step - loss: 0.6771 - accuracy: 0.9935 - val_loss: 0.8158 - val_accuracy: 0.9407
# Epoch 71/100
# 20/20 [==============================] - ETA: 0s - loss: 0.6523 - accuracy: 0.9969
# Epoch 71: val_loss improved from 0.81585 to 0.79973, saving model to model_weights.h5
# 20/20 [==============================] - 24s 1s/step - loss: 0.6523 - accuracy: 0.9969 - val_loss: 0.7997 - val_accuracy: 0.9467
# Epoch 72/100
# 20/20 [==============================] - ETA: 0s - loss: 0.6458 - accuracy: 0.9969
# Epoch 72: val_loss improved from 0.79973 to 0.79932, saving model to model_weights.h5
# 20/20 [==============================] - 23s 1s/step - loss: 0.6458 - accuracy: 0.9969 - val_loss: 0.7993 - val_accuracy: 0.9407
# Epoch 73/100
# 20/20 [==============================] - ETA: 0s - loss: 0.6338 - accuracy: 0.9937
# Epoch 73: val_loss improved from 0.79932 to 0.78451, saving model to model_weights.h5
# 20/20 [==============================] - 23s 1s/step - loss: 0.6338 - accuracy: 0.9937 - val_loss: 0.7845 - val_accuracy: 0.9407
# Epoch 74/100
# 20/20 [==============================] - ETA: 0s - loss: 0.6203 - accuracy: 0.9953
# Epoch 74: val_loss improved from 0.78451 to 0.74300, saving model to model_weights.h5
# 20/20 [==============================] - 24s 1s/step - loss: 0.6203 - accuracy: 0.9953 - val_loss: 0.7430 - val_accuracy: 0.9526
# Epoch 75/100
# 20/20 [==============================] - ETA: 0s - loss: 0.6084 - accuracy: 0.9969
# Epoch 75: val_loss did not improve from 0.74300
# 20/20 [==============================] - 23s 1s/step - loss: 0.6084 - accuracy: 0.9969 - val_loss: 0.7605 - val_accuracy: 0.9481
# Epoch 76/100
# 20/20 [==============================] - ETA: 0s - loss: 0.5836 - accuracy: 0.9969
# Epoch 76: val_loss did not improve from 0.74300
# 20/20 [==============================] - 23s 1s/step - loss: 0.5836 - accuracy: 0.9969 - val_loss: 0.7460 - val_accuracy: 0.9526
# Epoch 77/100
# 20/20 [==============================] - ETA: 0s - loss: 0.5866 - accuracy: 0.9953
# Epoch 77: val_loss improved from 0.74300 to 0.73964, saving model to model_weights.h5
# 20/20 [==============================] - 25s 1s/step - loss: 0.5866 - accuracy: 0.9953 - val_loss: 0.7396 - val_accuracy: 0.9481
# Epoch 78/100
# 20/20 [==============================] - ETA: 0s - loss: 0.5656 - accuracy: 0.9953
# Epoch 78: val_loss improved from 0.73964 to 0.72302, saving model to model_weights.h5
# 20/20 [==============================] - 24s 1s/step - loss: 0.5656 - accuracy: 0.9953 - val_loss: 0.7230 - val_accuracy: 0.9481
# Epoch 79/100
# 20/20 [==============================] - ETA: 0s - loss: 0.5707 - accuracy: 0.9937
# Epoch 79: val_loss improved from 0.72302 to 0.70574, saving model to model_weights.h5
# 20/20 [==============================] - 24s 1s/step - loss: 0.5707 - accuracy: 0.9937 - val_loss: 0.7057 - val_accuracy: 0.9511
# Epoch 80/100
# 20/20 [==============================] - ETA: 0s - loss: 0.5522 - accuracy: 1.0000
# Epoch 80: val_loss did not improve from 0.70574
# 20/20 [==============================] - 22s 1s/step - loss: 0.5522 - accuracy: 1.0000 - val_loss: 0.7860 - val_accuracy: 0.9304
# Epoch 81/100
# 20/20 [==============================] - ETA: 0s - loss: 0.5689 - accuracy: 0.9922
# Epoch 81: val_loss did not improve from 0.70574
# 20/20 [==============================] - 24s 1s/step - loss: 0.5689 - accuracy: 0.9922 - val_loss: 0.7592 - val_accuracy: 0.9348
# Epoch 82/100
# 20/20 [==============================] - ETA: 0s - loss: 0.5530 - accuracy: 0.9953
# Epoch 82: val_loss did not improve from 0.70574
# 20/20 [==============================] - 23s 1s/step - loss: 0.5530 - accuracy: 0.9953 - val_loss: 0.7472 - val_accuracy: 0.9319
# Epoch 83/100
# 20/20 [==============================] - ETA: 0s - loss: 0.5519 - accuracy: 0.9935
# Epoch 83: val_loss did not improve from 0.70574
# 20/20 [==============================] - 22s 1s/step - loss: 0.5519 - accuracy: 0.9935 - val_loss: 0.7513 - val_accuracy: 0.9333
# Epoch 84/100
# 20/20 [==============================] - ETA: 0s - loss: 0.5419 - accuracy: 0.9937
# Epoch 84: val_loss did not improve from 0.70574
# 20/20 [==============================] - 23s 1s/step - loss: 0.5419 - accuracy: 0.9937 - val_loss: 0.7315 - val_accuracy: 0.9422
# Epoch 84: early stopping

# %%
def plot_training(hist):
    '''
    This function take training model and plot history of accuracy and losses with the best epoch in both of them.
    '''

    tr_acc = hist.history['accuracy']
    tr_loss = hist.history['loss']
    val_acc = hist.history['val_accuracy']
    val_loss = hist.history['val_loss']
    index_loss = np.argmin(val_loss)
    val_lowest = val_loss[index_loss]
    index_acc = np.argmax(val_acc)
    acc_highest = val_acc[index_acc]
    Epochs = [i+1 for i in range(len(tr_acc))]
    loss_label = f'best epoch= {str(index_loss + 1)}'
    acc_label = f'best epoch= {str(index_acc + 1)}'

    plt.figure(figsize= (20, 8))
    plt.style.use('fivethirtyeight')

    plt.subplot(1, 2, 1)
    plt.plot(Epochs, tr_loss, 'r', label= 'Training loss')
    plt.plot(Epochs, val_loss, 'g', label= 'Validation loss')
    plt.scatter(index_loss + 1, val_lowest, s= 150, c= 'blue', label= loss_label)
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(Epochs, tr_acc, 'r', label= 'Training Accuracy')
    plt.plot(Epochs, val_acc, 'g', label= 'Validation Accuracy')
    plt.scatter(index_acc + 1 , acc_highest, s= 150, c= 'blue', label= acc_label)
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.tight_layout
    plt.show()

# %%
plot_training(history)

# %% [markdown]
# ### Evaluating the Model

# %%
ts_length = len(test_df)
test_batch_size = max(sorted([ts_length // n for n in range(1, ts_length + 1) if ts_length%n == 0 and ts_length/n <= 80]))
test_steps = ts_length // test_batch_size

train_score = model.evaluate(train_gen, steps= test_steps, verbose= 1)
valid_score = model.evaluate(valid_gen, steps= test_steps, verbose= 1)
test_score = model.evaluate(test_gen, steps= test_steps, verbose= 1)

print("Train Loss: ", train_score[0])
print("Train Accuracy: ", train_score[1])
print('-' * 20)
print("Validation Loss: ", valid_score[0])
print("Validation Accuracy: ", valid_score[1])
print('-' * 20)
print("Test Loss: ", test_score[0])
print("Test Accuracy: ", test_score[1])
# Out:
# 9/9 [==============================] - 2s 246ms/step - loss: 0.4600 - accuracy: 1.0000
# 9/9 [==============================] - 4s 418ms/step - loss: 0.6851 - accuracy: 0.9549
# 9/9 [==============================] - 181s 22s/step - loss: 0.6970 - accuracy: 0.9467
# Train Loss:  0.45998796820640564
# Train Accuracy:  1.0
# --------------------
# Validation Loss:  0.685107946395874
# Validation Accuracy:  0.9548611044883728
# --------------------
# Test Loss:  0.6970170736312866
# Test Accuracy:  0.9466666579246521

# %%
y_pred = model.predict(test_gen)
y_pred_labels = np.argmax(y_pred, axis=1)
y_true_labels = test_gen.classes
# Out:
# 9/9 [==============================] - 5s 537ms/step

# %%
class_names = list(test_gen.class_indices.keys())

confusion_mtx = confusion_matrix(y_true_labels, y_pred_labels)

plt.figure(figsize=(12, 10))  # Increase the size of the plot

# Use the heatmap function to display the confusion matrix with better formatting
sns.heatmap(confusion_mtx, cmap="Blues", annot=True, fmt="d", xticklabels=class_names, yticklabels=class_names, cbar=False)

plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")

# Rotate the tick labels for better readability
plt.xticks(rotation=90)
plt.yticks(rotation=0)

plt.show()

# %% [markdown]
# ## Generate Classification Report

# %%
report = classification_report(y_true_labels, y_pred_labels, target_names=class_names)

print("Classification Report: ")
print(report)
# Out:
# Classification Report:
#                         precision    recall  f1-score   support
#
#         Astrocitoma T1       0.96      0.89      0.92        27
#       Astrocitoma T1C+       0.97      0.97      0.97        35
#         Astrocitoma T2       0.92      0.92      0.92        25
#           Carcinoma T1       1.00      0.90      0.95        10
#         Carcinoma T1C+       1.00      0.94      0.97        17
#           Carcinoma T2       1.00      0.91      0.95        11
#          Ependimoma T1       0.88      1.00      0.93         7
#        Ependimoma T1C+       1.00      0.71      0.83         7
#          Ependimoma T2       0.89      1.00      0.94         8
#       Ganglioglioma T1       1.00      0.67      0.80         3
#     Ganglioglioma T1C+       0.50      1.00      0.67         2
#       Ganglioglioma T2       0.00      0.00      0.00         4
#           Germinoma T1       1.00      1.00      1.00         4
#         Germinoma T1C+       1.00      1.00      1.00         6
#           Germinoma T2       1.00      1.00      1.00         5
#        Glioblastoma T1       1.00      1.00      1.00         9
#      Glioblastoma T1C+       0.93      1.00      0.97        14
#        Glioblastoma T2       0.88      0.88      0.88         8
#           Granuloma T1       1.00      0.80      0.89         5
#         Granuloma T1C+       1.00      0.80      0.89         5
#           Granuloma T2       0.33      0.50      0.40         2
#      Meduloblastoma T1       1.00      1.00      1.00         3
#    Meduloblastoma T1C+       1.00      1.00      1.00        10
#      Meduloblastoma T2       0.67      0.67      0.67         6
#          Meningioma T1       0.95      0.95      0.95        41
#        Meningioma T1C+       0.93      0.96      0.95        56
#          Meningioma T2       0.92      0.94      0.93        35
#         Neurocitoma T1       0.95      1.00      0.97        19
#       Neurocitoma T1C+       0.97      1.00      0.99        34
#         Neurocitoma T2       0.94      1.00      0.97        16
#   Oligodendroglioma T1       1.00      1.00      1.00        13
# Oligodendroglioma T1C+       1.00      0.91      0.95        11
#   Oligodendroglioma T2       0.91      1.00      0.95        10
#            Papiloma T1       0.91      1.00      0.95        10
#          Papiloma T1C+       1.00      0.94      0.97        16
#            Papiloma T2       1.00      0.80      0.89        10
#          Schwannoma T1       1.00      1.00      1.00        22
#        Schwannoma T1C+       0.97      1.00      0.98        29
#          Schwannoma T2       0.86      0.90      0.88        20
#         Tuberculoma T1       1.00      1.00      1.00         4
#       Tuberculoma T1C+       1.00      0.92      0.96        12
#         Tuberculoma T2       1.00      0.80      0.89         5
#             _NORMAL T1       0.95      1.00      0.97        38
#             _NORMAL T2       0.95      1.00      0.98        41
#
#               accuracy                           0.95       675
#              macro avg       0.91      0.90      0.90       675
#           weighted avg       0.94      0.95      0.94       675
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ## VGG19

# %%
tr_gen = ImageDataGenerator(preprocessing_function= scalar,
                            horizontal_flip= True)

ts_gen = ImageDataGenerator(preprocessing_function= scalar)

train_gen = tr_gen.flow_from_dataframe( train_df,
                                       x_col= 'image_path',
                                       y_col= 'label',
                                       target_size= img_size,
                                       class_mode= 'categorical',
                                       color_mode= color,
                                       shuffle= True,
                                       batch_size= batch_size)

valid_gen = ts_gen.flow_from_dataframe( valid_df,
                                       x_col= 'image_path',
                                       y_col= 'label',
                                       target_size= img_size,
                                       class_mode= 'categorical',
                                       color_mode= color,
                                       shuffle= True,
                                       batch_size= batch_size)

test_gen = ts_gen.flow_from_dataframe( test_df,
                                      x_col= 'image_path',
                                      y_col= 'label',
                                      target_size= img_size,
                                      class_mode= 'categorical',
                                      color_mode= color,
                                      shuffle= False,
                                      batch_size= test_batch_size)

# %%
class_count = len(list(train_gen.class_indices.keys()))

# %%
'''vgg19_base_model = tf.keras.applications.vgg19.VGG19(include_top= False,
                                                               weights= "imagenet",
                                                               input_shape= img_shape,
                                                               pooling= 'max')



vgg19_base_model.compile(Adamax(learning_rate= 0.001), loss= 'categorical_crossentropy', metrics= ['accuracy'])

#vgg19_base_model.summary()'''


vgg19_model = VGG19(include_top=False, pooling='avg', weights='imagenet', input_shape = (img_shape))
for layer in vgg19_model.layers:
    layer.trainable = False
# Check if all layers except conv5 layers are not trainable
#for i, layer in enumerate(res_model.layers):
#    print(i, layer.name, "-", layer.trainable)

# %%
#info about optimizers
model.optimizer.get_config()

# %%
early_stop = EarlyStopping(monitor='val_loss',
                           patience=5,
                           verbose=1)

checkpoint = ModelCheckpoint('model_weights.h5',
                             monitor='val_loss',
                             save_best_only=True,
                             save_weights_only=True,
                             mode='min',
                             verbose=1)


'''history_vgg19 = vgg19_base_model.fit(x= train_gen,
                    epochs= 200,
                    callbacks=[early_stop, checkpoint],
                    validation_data= valid_gen)'''

# %%
history_vgg19 = model.fit(x= train_gen,
                    steps_per_epoch = 20,
                    epochs = 100,
                    verbose = 1,
                    validation_data = valid_gen,
                    callbacks = [early_stop, checkpoint])

# %%
# visualize the model accuracy for the training data and Validation data
plt.plot(history_vgg19.history['accuracy'], label='Train')
plt.plot(history_vgg19.history['val_accuracy'], label='Validation')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend()
plt.show()

# visualize the model loss for the training data and Validation data
plt.plot(history_vgg19.history['loss'], label='Train')
plt.plot(history_vgg19.history['val_loss'], label='Validation')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend()
plt.show()

# %%
result = model.evaluate(test_gen)

# %%
y_pred = model.predict(test_gen)

y_pred_labels = np.argmax(y_pred, axis=1)

y_true_labels = test_gen.classes

# %%
class_names = list(test_gen.class_indices.keys())

confusion_mtx = confusion_matrix(y_true_labels, y_pred_labels)

plt.figure(figsize=(10,8))
sns.heatmap(confusion_mtx, cmap="Blues", annot=True, fmt="d", xticklabels=class_names, yticklabels=class_names)
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()
